# %%
import pandas as pd 
import numpy as np
import os
import scipy.stats as stats

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
# %pylab inline
matplotlib.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#read germline data from dbGAP
germline_data = pd.read_csv("germline_mutations_V3.txt",
                           sep = '\t')

# %%
germline_data['Patient_ID'] = germline_data['patient']
germline_data['bi-allelic'] = np.where(germline_data['biallelic_type']=='None', 0, 1)
germline_data = germline_data[['Patient_ID', 'penetrance', 'bi-allelic']]
germline_data = germline_data.sort_values(['Patient_ID', 'penetrance', 'bi-allelic' ], 
                                            ascending = [True, True, False])
germline_data = germline_data.drop_duplicates(subset = 'Patient_ID')

# %%
#read clinical data (supplementary table Sx) saved as text file
tumortype_info = pd.read_csv("supplementary_clinical.txt",sep = '\t')
dict_tumortype = dict(zip(tumortype_info['Patient'], tumortype_info['Cancer Type']))

# %%
#oncogenic mutation status for cohort excluding hyper mutated cases
somatic_oncogenic_status = pd.read_csv("../data/all_somatic_drivers.txt",
                                        sep = '\t')
print somatic_oncogenic_status.head()
somatic_oncogenic_status['cancer_type'] = somatic_oncogenic_status['Patient_ID'].map(dict_tumortype)
somatic_oncogenic_status = pd.merge(somatic_oncogenic_status, germline_data, on = 'Patient_ID', how = 'left')


print somatic_oncogenic_status.shape
somatic_oncogenic_status.head()
# Out:
#           Patient_ID               Tumor_Sample  n_drivers  n_all_drivers
# 0  A-c0cfec74b8666bf  A-c0cfec74b8666bf-T01-IM5        0.0            1.0
# 1     A-fb1cda9f4919     A-fb1cda9f4919-T02-IM5        1.0            4.0
# 2     A-c3446f9e3370     A-c3446f9e3370-T01-IM6        0.0            6.0
# 3     A-0c2e7b660c55     A-0c2e7b660c55-T01-IM5        1.0            1.0
# 4  A-faf64244d53dbc7  A-faf64244d53dbc7-T01-IM6        1.0            2.0
# (13648, 7)
#           Patient_ID               Tumor_Sample  n_drivers  n_all_drivers  \
# 0  A-c0cfec74b8666bf  A-c0cfec74b8666bf-T01-IM5        0.0            1.0
# 1     A-fb1cda9f4919     A-fb1cda9f4919-T02-IM5        1.0            4.0
# 2     A-c3446f9e3370     A-c3446f9e3370-T01-IM6        0.0            6.0
# 3     A-0c2e7b660c55     A-0c2e7b660c55-T01-IM5        1.0            1.0
# 4  A-faf64244d53dbc7  A-faf64244d53dbc7-T01-IM6        1.0            2.0
#
#                       cancer_type penetrance  bi-allelic
# 0                 Prostate Cancer        NaN         NaN
# 1  Gastrointestinal Stromal Tumor        NaN         NaN
# 2                  Ovarian Cancer        Low         0.0
# 3                           Other        NaN         NaN
# 4       Colorectal Adenocarcinoma        NaN         NaN

# %%
#subset of patients with one or more drivers

penetrance_order = {'High':1, 'Moderate':2, 'Low':3, 'Uncertain':4}

somatic_oncogenic_status['penetrance_order'] = somatic_oncogenic_status['penetrance'].map(penetrance_order)
penetrance = 'High'
hi_pen = somatic_oncogenic_status[(somatic_oncogenic_status['penetrance'] == penetrance) ]
tumortypes_included = hi_pen['cancer_type'].unique().tolist()

pts_hi_pen_het = hi_pen[hi_pen['bi-allelic']==0]['Patient_ID'].unique().tolist()
pts_hi_pen_biallelic = hi_pen[hi_pen['bi-allelic']==1]['Patient_ID'].unique().tolist()
lower_pen = somatic_oncogenic_status[somatic_oncogenic_status['penetrance_order'] > penetrance_order[penetrance]]
pts_lower_pen = lower_pen['Patient_ID'].unique().tolist()
    
gl_wt_type = somatic_oncogenic_status[(~(somatic_oncogenic_status['Patient_ID'].isin(pts_hi_pen_het))) &
                                      (~(somatic_oncogenic_status['Patient_ID'].isin(pts_hi_pen_biallelic))) &
                                          (~(somatic_oncogenic_status['Patient_ID'].isin(pts_lower_pen))) &
                                         (somatic_oncogenic_status['cancer_type'].isin(tumortypes_included))]['Patient_ID'].unique().tolist()

# %%
somatic_oncogenic_status['gl_status'] = np.where(somatic_oncogenic_status['Patient_ID'].isin(pts_hi_pen_biallelic),
                                                 "biallelic", 
                                                 "wildtype")
somatic_oncogenic_status['gl_status'] = np.where(somatic_oncogenic_status['Patient_ID'].isin(pts_hi_pen_het),
                                                 "heterozygous", 
                                                 somatic_oncogenic_status['gl_status'])
somatic_oncogenic_status['gl_status'] = np.where(somatic_oncogenic_status['Patient_ID'].isin(pts_lower_pen),
                                                 "M/L/U", 
                                                 somatic_oncogenic_status['gl_status'])
                                                 
                                                 
summary_counts = pd.DataFrame({
        'tumortype_count' : 
        somatic_oncogenic_status.groupby(['gl_status'])['Patient_ID'].nunique(),
   }).reset_index()
print summary_counts
# Out:
#       gl_status  tumortype_count
# 0         M/L/U             1609
# 1     biallelic              400
# 2  heterozygous              211
# 3      wildtype            11428

# %%
cancertype_counts = pd.DataFrame({
        'tumortype_count' : 
        somatic_oncogenic_status.groupby(['cancer_type'])['Patient_ID'].nunique(),
   }).reset_index()

dict_cancertype_count = dict(zip(cancertype_counts['cancer_type'], cancertype_counts['tumortype_count']))
cancertype_counts.head()
# Out:
#                   cancer_type  tumortype_count
# 0    Adrenocortical Carcinoma               32
# 1         Ampullary Carcinoma               37
# 2                 Anal Cancer               40
# 3  Appendiceal Adenocarcinoma               91
# 4              Bladder Cancer              356

# %%
gl_frequencies_tumortype = pd.DataFrame({
        'glcount_tumortype' : 
        somatic_oncogenic_status[somatic_oncogenic_status['penetrance']=='High'].groupby([ 'cancer_type',
                                         'bi-allelic'])['Patient_ID'].nunique(),
    }).reset_index()
gl_frequencies_tumortype = gl_frequencies_tumortype.pivot_table(index = [ 'cancer_type' ],
                                                         columns = ['bi-allelic'],
                                                         values = 'glcount_tumortype').reset_index()
gl_frequencies_tumortype.head()

gl_frequencies_tumortype.columns = ['cancer_type', 'all_het','all_biallelic',]
gl_frequencies_tumortype['all_gl'] = gl_frequencies_tumortype['all_het']+gl_frequencies_tumortype['all_biallelic']
gl_frequencies_tumortype = gl_frequencies_tumortype.fillna(0)
gl_frequencies_tumortype = pd.merge(gl_frequencies_tumortype, cancertype_counts, on = ['cancer_type'],
                                   how = 'left')
gl_frequencies_tumortype['gl_wt_count_tumortype'] = (gl_frequencies_tumortype['tumortype_count'] - gl_frequencies_tumortype['all_gl'])
gl_frequencies_tumortype.head()
# Out:
#                   cancer_type  all_het  all_biallelic  all_gl  \
# 0    Adrenocortical Carcinoma      0.0            2.0     0.0
# 1         Ampullary Carcinoma      1.0            3.0     4.0
# 2                 Anal Cancer      2.0            0.0     0.0
# 3  Appendiceal Adenocarcinoma      2.0            0.0     0.0
# 4              Bladder Cancer      8.0            3.0    11.0
#
#    tumortype_count  gl_wt_count_tumortype
# 0               32                   32.0
# 1               37                   33.0
# 2               40                   40.0
# 3               91                   91.0
# 4              356                  345.0

# %%
gl_frequencies_tumortype_LP = pd.DataFrame({
        'count_lower_pen' : 
        somatic_oncogenic_status[somatic_oncogenic_status['penetrance'].isin(['Moderate',
                                                           'Low', 'Uncertain'])].groupby([ 'cancer_type',
                                         ])['Patient_ID'].nunique(),
    }).reset_index()
gl_frequencies_tumortype_LP.head()
gl_frequencies_tumortype_LP = pd.merge(gl_frequencies_tumortype_LP, cancertype_counts, on = ['cancer_type'],
                                   how = 'left')
gl_frequencies_tumortype_LP.head()
# Out:
#                   cancer_type  count_lower_pen  tumortype_count
# 0    Adrenocortical Carcinoma                3               32
# 1         Ampullary Carcinoma                6               37
# 2                 Anal Cancer                8               40
# 3  Appendiceal Adenocarcinoma                4               91
# 4              Bladder Cancer               35              356

# %%
import random
clinical_data = somatic_oncogenic_status[['cancer_type', 'Patient_ID', 'gl_status']]

all_wt_tumortype_merge = []

df_wildtype = pd.DataFrame(columns = ['cancer_type','Patient_ID', 'gl_status', 'sample'])
df_wildtype_het = pd.DataFrame(columns = ['cancer_type','Patient_ID', 'gl_status', 'sample'])
df_wildtype_LP = pd.DataFrame(columns = ['cancer_type','Patient_ID', 'gl_status', 'sample'])

#for each cancertype, sample patients who are wild type / carriers of low/mod/uncertain penetrance variants to have the same count as high penetrance carriers.

for cancertype in clinical_data['cancer_type'].unique().tolist():
    if(cancertype<>'Unknown'):
        try:
            count_cancertype = dict_cancertype_count[cancertype]

            if(count_cancertype > 5):
                #print cancertype
                count_non_cancertype = clinical_data.shape[0] - count_cancertype

                proportion_biallelic = gl_frequencies_tumortype[gl_frequencies_tumortype['cancer_type']==cancertype]['all_biallelic'].values[0]
                proportion_het = gl_frequencies_tumortype[gl_frequencies_tumortype['cancer_type']==cancertype]['all_het'].values[0]
                proportion_LP = gl_frequencies_tumortype_LP[gl_frequencies_tumortype_LP['cancer_type']==cancertype
                                                           ]['count_lower_pen'].values[0]

                clinical_cancertype = clinical_data[(clinical_data['cancer_type']==cancertype)]
                wt_indices = clinical_cancertype[(clinical_cancertype['gl_status']=='wildtype')].index.tolist()

                n_simulations = 100
                

                for i in range(n_simulations):
                    #generate WT retaining biallelic proportion
                    try:
                        sample_wt_bi_proportion = clinical_cancertype[clinical_cancertype.index.isin(random.sample(wt_indices,  int(proportion_biallelic)))]
                    except ValueError:
                        sample_wt_bi_proportion = clinical_cancertype[clinical_cancertype.index.isin(wt_indices)]
                        
                    wt_sample = sample_wt_bi_proportion
                    wt_sample['sample'] = i
                    wt_sample['gl_status'] = 'WildType/bi'
                    df_wildtype = pd.concat([df_wildtype, wt_sample ])
                    
                    #generate WT retaining het proportion
                    try:
                        sample_wt_het_proportion = clinical_cancertype[clinical_cancertype.index.isin(random.sample(wt_indices,  int(proportion_het)))]
                    except ValueError:
                         sample_wt_het_proportion = clinical_cancertype[clinical_cancertype.index.isin(wt_indices)]
                         
                    wt_sample = sample_wt_het_proportion
                    wt_sample['sample'] = i
                    wt_sample['gl_status'] = 'WildType/het'
                    
                    df_wildtype_het = pd.concat([df_wildtype_het, wt_sample ])
                    
                    #generate WT retaining lower penetrance proportion
                    try:
                        sample_wt_LP_proportion = clinical_cancertype[clinical_cancertype.index.isin(random.sample(wt_indices,  int(proportion_LP)))]
                    except ValueError:
                        sample_wt_LP_proportion = clinical_cancertype[clinical_cancertype.index.isin(wt_indices)]
                        

                    wt_sample = sample_wt_LP_proportion
                    wt_sample['sample'] = i
                    wt_sample['gl_status'] = 'WildType/LP'
                    df_wildtype_LP = pd.concat([df_wildtype_LP, wt_sample ])


        except KeyError:
                pass

print df_wildtype.head()
print df_wildtype_het.head()
print df_wildtype_LP.head()
#this df shows the sampling results
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           cancer_type         Patient_ID    gl_status sample
# 276   Prostate Cancer  A-87c635655fd03c6  WildType/bi      0
# 408   Prostate Cancer     A-c34c9a226f7c  WildType/bi      0
# 489   Prostate Cancer  A-94e8d954283c6d8  WildType/bi      0
# 751   Prostate Cancer  A-6bbe139c492d072  WildType/bi      0
# 2016  Prostate Cancer  A-ad76301485fa46d  WildType/bi      0
#           cancer_type         Patient_ID     gl_status sample
# 108   Prostate Cancer  A-464a4c080639583  WildType/het      0
# 1228  Prostate Cancer     A-b8ec134d4145  WildType/het      0
# 1238  Prostate Cancer  A-d2123e8602f03a4  WildType/het      0
# 1398  Prostate Cancer  A-eadce92602c5ca7  WildType/het      0
# 1664  Prostate Cancer  A-f0c0c96fe7da4f6  WildType/het      0
#          cancer_type         Patient_ID    gl_status sample
# 35   Prostate Cancer  A-5a45ea871cecae0  WildType/LP      0
# 91   Prostate Cancer     A-53ad8d9a1ce5  WildType/LP      0
# 107  Prostate Cancer  A-205d4ccc6873436  WildType/LP      0
# 132  Prostate Cancer  A-31ccbafb5746c70  WildType/LP      0
# 174  Prostate Cancer     A-2c7b6bb9b201  WildType/LP      0

# %%
print df_wildtype.shape
print df_wildtype_het.shape
print df_wildtype_LP.shape
# Out:
# (40000, 4)
# (21000, 4)
# (160900, 4)

# %%
#summarize the sampled data to get proportion of patients with somatic oncogenic mutations.
#retain the sample level summary to generate confidence intervals later
list_columns = [ 'penetrance', 'group', 'gl_count', 'somatic_count',]
penetrance_order = {'High':1, 'Moderate':2, 'Low':3, 'Uncertain':4}

somatic_oncogenic_status['penetrance_order'] = somatic_oncogenic_status['penetrance'].map(penetrance_order)
keep_tumortypes = [i for i in dict_cancertype_count.keys() if dict_cancertype_count[i]> 5]
somatic_oncogenic_status_tumortypes = somatic_oncogenic_status[somatic_oncogenic_status['cancer_type'].isin(keep_tumortypes)]

somatic_mutations_oncogenes_keep_tumortypes = somatic_oncogenic_status_tumortypes[somatic_oncogenic_status_tumortypes['n_drivers']>0]
somatic_mutations_oncogenes_all = somatic_oncogenic_status[somatic_oncogenic_status['n_drivers']>0]

wt_bi_df = pd.DataFrame(columns = list_columns+['sample'])
wt_het_df = pd.DataFrame(columns = list_columns+['sample'])
wt_LP_df = pd.DataFrame(columns = list_columns+['sample'])


for i in df_wildtype['sample'].unique().tolist():
        gl_wt_type = df_wildtype[df_wildtype['sample'] == i]['Patient_ID'].tolist()
        somatic_mutations_gl_wt = somatic_mutations_oncogenes_keep_tumortypes[somatic_mutations_oncogenes_keep_tumortypes['Patient_ID'].isin(gl_wt_type)]['Patient_ID'].unique().tolist()
        temp_df = pd.DataFrame([[penetrance, "WildType/bi", len(gl_wt_type), len(somatic_mutations_gl_wt), i
                                                               ]], columns=wt_bi_df.columns.tolist())
        wt_bi_df = pd.concat([wt_bi_df, temp_df])
        
print wt_bi_df.head()
print wt_bi_df.shape
mean_somatic_count = np.average(wt_bi_df['somatic_count'].tolist())
print mean_somatic_count
wt_df_onc = wt_bi_df[['penetrance', 'group', 'gl_count']].drop_duplicates()
wt_df_onc['somatic_count'] = mean_somatic_count




for i in df_wildtype_het['sample'].unique().tolist():
        gl_het = df_wildtype_het[df_wildtype_het['sample'] == i]['Patient_ID'].tolist()
        somatic_mutations_gl_het = somatic_mutations_oncogenes_keep_tumortypes[somatic_mutations_oncogenes_keep_tumortypes['Patient_ID'].isin(gl_het)]['Patient_ID'].unique().tolist()
        temp_df = pd.DataFrame([[penetrance, "WildType/het", len(gl_het), len(somatic_mutations_gl_het), i
                                                               ]], columns=wt_bi_df.columns.tolist())
        wt_het_df = pd.concat([wt_het_df, temp_df])
        
print wt_het_df.head()
print wt_het_df.shape
mean_somatic_count = np.average(wt_het_df['somatic_count'].tolist())
print mean_somatic_count
wt_het_df_onc = wt_het_df[['penetrance', 'group', 'gl_count']].drop_duplicates()
wt_het_df_onc['somatic_count'] = mean_somatic_count




for i in df_wildtype_LP['sample'].unique().tolist():
        gl_lower_pen = df_wildtype_LP[df_wildtype_LP['sample'] == i]['Patient_ID'].tolist()
        somatic_mutations_gl_LP = somatic_mutations_oncogenes_keep_tumortypes[somatic_mutations_oncogenes_keep_tumortypes['Patient_ID'].isin(gl_lower_pen)]['Patient_ID'].unique().tolist()
        temp_df = pd.DataFrame([[penetrance, "WildType/LP", len(gl_lower_pen), len(somatic_mutations_gl_LP), i
                                                               ]], columns=wt_bi_df.columns.tolist())
        wt_LP_df = pd.concat([wt_LP_df, temp_df])
        
print wt_LP_df.head()
print wt_LP_df.shape
mean_somatic_count = np.average(wt_LP_df['somatic_count'].tolist())
print mean_somatic_count
wt_LP_df_onc = wt_LP_df[['penetrance', 'group', 'gl_count']].drop_duplicates()
wt_LP_df_onc['somatic_count'] = mean_somatic_count

#wt_df_onc['proportion_oncogenic'] = wt_df_onc['somatic_count']/(wt_df_onc['gl_count']+.000000001)
# Out:
#   penetrance        group gl_count somatic_count sample
# 0       High  WildType/bi      400           222      0
# 0       High  WildType/bi      400           213      1
# 0       High  WildType/bi      400           225      2
# 0       High  WildType/bi      400           211      3
# 0       High  WildType/bi      400           218      4
# (100, 5)
# 215.5
#   penetrance         group gl_count somatic_count sample
# 0       High  WildType/het      210           124      0
# 0       High  WildType/het      210           122      1
# 0       High  WildType/het      210           125      2
# 0       High  WildType/het      210           124      3
# 0       High  WildType/het      210           119      4
# (100, 5)
# 123.03
#   penetrance        group gl_count somatic_count sample
# 0       High  WildType/LP     1609           908      0
# 0       High  WildType/LP     1609           899      1
# 0       High  WildType/LP     1609           882      2
# 0       High  WildType/LP     1609           892      3
# 0       High  WildType/LP     1609           910      4
# (100, 5)
# 901.56

# %%
#get somatic oncogenic rates for high penetrance carriers and merge with lower penetrance + wildtype
for penetrance in ['High']:
    hi_pen = somatic_oncogenic_status[(somatic_oncogenic_status['penetrance'] == penetrance) ]
    
    
    pts_hi_pen_het = hi_pen[hi_pen['bi-allelic']==0]['Patient_ID'].unique().tolist()
    pts_hi_pen_biallelic = hi_pen[hi_pen['bi-allelic']==1]['Patient_ID'].unique().tolist()
    pts_lower_pen = somatic_oncogenic_status[(somatic_oncogenic_status['penetrance'].isin(['Moderate', 
                                               'Low', 'Uncertain'])) ]['Patient_ID'].unique().tolist()
    
    somatic_mutations_gl_het = somatic_mutations_oncogenes_all[somatic_mutations_oncogenes_all['Patient_ID'].isin(pts_hi_pen_het)]['Patient_ID'].unique().tolist()
    somatic_mutations_gl_biallelic = somatic_mutations_oncogenes_all[somatic_mutations_oncogenes_all['Patient_ID'].isin(pts_hi_pen_biallelic)]['Patient_ID'].unique().tolist()
    somatic_mutations_gl_LP = somatic_mutations_oncogenes_all[somatic_mutations_oncogenes_all['Patient_ID'].isin(pts_lower_pen)]['Patient_ID'].unique().tolist()
    
    temp_df1 = pd.DataFrame([[penetrance, "Heterozygous_all", len(pts_hi_pen_het), len(somatic_mutations_gl_het)
                                                               ]], columns=list_columns)
    
    temp_df2 = pd.DataFrame([[penetrance, "Biallelic_all", len(pts_hi_pen_biallelic), len(somatic_mutations_gl_biallelic)
                                                               ]], columns=list_columns)
    temp_df3 = pd.DataFrame([[penetrance, "LowerPen_all", len(pts_lower_pen), len(somatic_mutations_gl_LP)
                                                               ]], columns=list_columns)
    
    somatic_oncogenic_by_gl = pd.concat([temp_df2, temp_df1, temp_df3, wt_het_df_onc,
                                        wt_df_onc, wt_LP_df_onc
                                        ])


somatic_oncogenic_by_gl['proportion_oncogenic'] = np.where(somatic_oncogenic_by_gl['gl_count']==0, 
                                                           0,
                              somatic_oncogenic_by_gl['somatic_count']/(somatic_oncogenic_by_gl['gl_count']+.000000001))
somatic_oncogenic_by_gl['somatic_wt'] = somatic_oncogenic_by_gl['gl_count'] - somatic_oncogenic_by_gl['somatic_count']
   
somatic_oncogenic_by_gl = somatic_oncogenic_by_gl.sort_values(['penetrance','group'])



somatic_oncogenic_by_gl
# Out:
#   penetrance             group gl_count  somatic_count proportion_oncogenic  \
# 0       High     Biallelic_all      400         142.00                0.355
# 0       High  Heterozygous_all      211         108.00             0.511848
# 0       High      LowerPen_all     1609         919.00             0.571162
# 0       High       WildType/LP     1609         901.56             0.560323
# 0       High       WildType/bi      400         215.50              0.53875
# 0       High      WildType/het      210         123.03             0.585857
#
#   somatic_wt
# 0        258
# 0        103
# 0        690
# 0     707.44
# 0      184.5
# 0      86.97

# %%
import statsmodels
import statsmodels.stats.api as sms
import numpy as np
import scipy.stats
from statsmodels.stats.proportion import (proportion_confint,
                                          multinomial_proportions_confint)
counts = pd.DataFrame({
        'count' : 
        somatic_oncogenic_status[somatic_oncogenic_status['cancer_type'].isin(keep_tumortypes)
                                ].groupby(['gl_status'])['Patient_ID'].nunique(),
    }).reset_index()
dict_counts = dict(zip(counts['gl_status'], counts['count']))

somatic_oncogenic_by_gl['gl_count_pre_sampling'] = np.where(somatic_oncogenic_by_gl['group'].str.startswith("WildType"),
                                                           dict_counts['wildtype'],
                                                           somatic_oncogenic_by_gl['gl_count'])
somatic_oncogenic_by_gl['estimated_somatic_count'] = somatic_oncogenic_by_gl['gl_count_pre_sampling'] *somatic_oncogenic_by_gl['proportion_oncogenic']
somatic_oncogenic_by_gl['estimated_somatic_count'] = somatic_oncogenic_by_gl['estimated_somatic_count'].astype(float)
somatic_oncogenic_by_gl['estimated_somatic_count'] = somatic_oncogenic_by_gl['estimated_somatic_count'].apply(np.ceil)

somatic_oncogenic_by_gl['lower'] =  somatic_oncogenic_by_gl.apply(
        lambda r: statsmodels.stats.proportion.proportion_confint(r.estimated_somatic_count, 
                                                                 r.gl_count_pre_sampling, 
                                                                  alpha=0.05, method='wilson')[0],
        axis=1)

somatic_oncogenic_by_gl['upper'] =  somatic_oncogenic_by_gl.apply(
        lambda r: statsmodels.stats.proportion.proportion_confint(r.estimated_somatic_count, 
                                                                 r.gl_count_pre_sampling, 
                                                                  alpha=0.05, method='wilson')[1],
        axis=1)


somatic_oncogenic_by_gl
# Out:
#   penetrance             group gl_count  somatic_count proportion_oncogenic  \
# 0       High     Biallelic_all      400         142.00                0.355
# 0       High  Heterozygous_all      211         108.00             0.511848
# 0       High      LowerPen_all     1609         919.00             0.571162
# 0       High       WildType/LP     1609         901.56             0.560323
# 0       High       WildType/bi      400         215.50              0.53875
# 0       High      WildType/het      210         123.03             0.585857
#
#   somatic_wt gl_count_pre_sampling  estimated_somatic_count     lower  \
# 0        258                   400                    142.0  0.309689
# 0        103                   211                    108.0  0.444796
# 0        690                  1609                    919.0  0.546839
# 0     707.44                 11428                   6404.0  0.551259
# 0      184.5                 11428                   6157.0  0.529613
# 0      86.97                 11428                   6696.0  0.576871
#
#       upper
# 0  0.403070
# 0  0.578477
# 0  0.595147
# 0  0.569456
# 0  0.547889
# 0  0.594930

# %%
f, ax = plt.subplots(figsize=(1.5, 4))
sns.set(font_scale=1.5)
#sns.set_style("whitegrid", {"axes.facecolor": "white"})
sns.set(style="ticks")

plot_data = somatic_oncogenic_by_gl.copy()
plot_data['group'] = plot_data['group'].str.split("_").str.get(0)
plot_data = plot_data.sort_values('group', ascending = False)
plot_data['error'] = plot_data['proportion_oncogenic'] - plot_data['lower']

ax.bar(plot_data['group'], plot_data['proportion_oncogenic'], 
                                     yerr=plot_data['error'], linewidth = 0,
                                     align='center', alpha=0.5, color = 'black')


ax.set_ylabel('Fraction of patients with somatic driver')
ax.set_xlabel('')
ax.set_ylim([0, 0.8])
plt.yticks(np.arange(0, 0.81, 0.2))
plt.xticks(rotation=90)
ax.xaxis.grid(False) 
ax.yaxis.grid(False)

# %%
plot_data
# Out:
#   penetrance         group gl_count  somatic_count proportion_oncogenic  \
# 0       High  WildType/het      210         123.03             0.585857
# 0       High   WildType/bi      400         215.50              0.53875
# 0       High   WildType/LP     1609         901.56             0.560323
# 0       High      LowerPen     1609         919.00             0.571162
# 0       High  Heterozygous      211         108.00             0.511848
# 0       High     Biallelic      400         142.00                0.355
#
#   somatic_wt gl_count_pre_sampling  estimated_somatic_count     lower  \
# 0      86.97                 11428                   6696.0  0.576871
# 0      184.5                 11428                   6157.0  0.529613
# 0     707.44                 11428                   6404.0  0.551259
# 0        690                  1609                    919.0  0.546839
# 0        103                   211                    108.0  0.444796
# 0        258                   400                    142.0  0.309689
#
#       upper       error
# 0  0.594930  0.00898598
# 0  0.547889  0.00913659
# 0  0.569456  0.00906398
# 0  0.595147   0.0243235
# 0  0.578477   0.0670523
# 0  0.403070    0.045311

# %%
chi2, p, dof, ex = stats.chi2_contingency([[plot_data[(plot_data['group']=='Heterozygous')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Heterozygous')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='Biallelic')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Biallelic')]['somatic_wt'].values[0]]], 
                                          correction=True) # het vs. biallelic
print p

chi2, p, dof, ex = stats.chi2_contingency([[plot_data[(plot_data['group']=='WildType/bi')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='WildType/bi')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='Biallelic')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Biallelic')]['somatic_wt'].values[0]]],
                                          correction=True) #wt vs. biallelic 
print p

chi2, p, dof, ex = stats.chi2_contingency([[plot_data[(plot_data['group']=='LowerPen')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='LowerPen')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='Biallelic')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Biallelic')]['somatic_wt'].values[0]]],
                                          correction=True) #lower pen vs. biallelic 
print p

chi2, p, dof, ex = stats.chi2_contingency([[plot_data[(plot_data['group']=='WildType/het')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='WildType/het')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='Heterozygous')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Heterozygous')]['somatic_wt'].values[0]]],
                                          correction=True) #wt vs. het 
print p

chi2, p, dof, ex = stats.chi2_contingency([[plot_data[(plot_data['group']=='WildType/LP')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='WildType/LP')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='LowerPen')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='LowerPen')]['somatic_wt'].values[0]]],
                                          correction=True) #wt vs. biallelic 
print p


chi2, p, dof, ex = stats.chi2_contingency([[plot_data[(plot_data['group']=='WildType/LP')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='WildType/LP')]['somatic_wt'].values[0]], 
                                           [plot_data[(plot_data['group']=='LowerPen')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='LowerPen')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='Heterozygous')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Heterozygous')]['somatic_wt'].values[0]],
                                           [plot_data[(plot_data['group']=='Biallelic')]['somatic_count'].values[0],
                                            plot_data[(plot_data['group']=='Biallelic')]['somatic_wt'].values[0]]], correction=True) #wt vs. het 
print p
# Out:
# 0.0002495139265211005
# 2.5267395464247565e-07
# 1.422771322480635e-14
# 0.15333151891905986
# 0.5587561035704804
# 5.649410882262787e-14

# %%
#get number of somatic mutations corresponding to sampled groups above.
#remember to also include those patients for which no somatic mutations were detected
gl_wt_type_sampled = df_wildtype['Patient_ID'].unique().tolist()
#gl_LP_type_sampled = df_lower_pen['Patient_ID'].unique().tolist()

number_of_drivers_WT = somatic_oncogenic_status[somatic_oncogenic_status['Patient_ID'].isin(gl_wt_type_sampled)][['Tumor_Sample',
                                                                                                   'n_all_drivers']]
number_of_drivers_WT['allele_state'] = "WildType"
#print number_of_drivers_WT
pts_somatic_mutations =  somatic_oncogenic_status['Patient_ID'].unique().tolist()

patients_no_drivers = [i for i in gl_wt_type_sampled if i not in pts_somatic_mutations]
df_nodrivers = pd.DataFrame(patients_no_drivers, columns=['Tumor_Sample'])
df_nodrivers['n_all_drivers'] = 0
df_nodrivers['allele_state'] = "WildType"
number_of_drivers_WT = pd.concat([number_of_drivers_WT, df_nodrivers])


number_of_drivers_LP = somatic_oncogenic_status[somatic_oncogenic_status['Patient_ID'].isin(gl_lower_pen)][['Tumor_Sample',
                                                                                                   'n_all_drivers']]
number_of_drivers_LP['allele_state'] = "M/L/U"

pts_somatic_mutations =  somatic_oncogenic_status['Patient_ID'].unique().tolist()

patients_no_drivers = [i for i in gl_lower_pen if i not in pts_somatic_mutations]
df_nodrivers = pd.DataFrame(patients_no_drivers, columns=['Tumor_Sample'])
df_nodrivers['n_all_drivers'] = 0
df_nodrivers['allele_state'] = "M/L/U"
number_of_drivers_LP = pd.concat([number_of_drivers_LP, df_nodrivers])


number_of_drivers_het = somatic_oncogenic_status[somatic_oncogenic_status['Patient_ID'].isin(pts_hi_pen_het)][['Tumor_Sample',
                                                                                                   'n_all_drivers']]

number_of_drivers_het['allele_state'] = "Heterozygous"

patients_no_drivers = [i for i in pts_hi_pen_het if i not in pts_somatic_mutations]
df_nodrivers = pd.DataFrame(patients_no_drivers,columns=['Tumor_Sample'])
df_nodrivers['n_all_drivers'] = 0
df_nodrivers['allele_state'] = "Heterozygous"
number_of_drivers_het = pd.concat([number_of_drivers_het, df_nodrivers])


number_of_drivers_biallelic = somatic_oncogenic_status[somatic_oncogenic_status['Patient_ID'].isin(pts_hi_pen_biallelic)
                                               ][['Tumor_Sample', 'n_all_drivers']]

 
print number_of_drivers_WT.shape, number_of_drivers_het.shape, number_of_drivers_biallelic.shape
number_of_drivers_biallelic['allele_state'] = "Biallelic"

patients_no_drivers = [i for i in pts_hi_pen_biallelic if i not in pts_somatic_mutations]
df_nodrivers = pd.DataFrame(patients_no_drivers,columns=['Tumor_Sample'])
df_nodrivers['n_all_drivers'] = 0
df_nodrivers['allele_state'] = "Biallelic"
number_of_drivers_biallelic = pd.concat([number_of_drivers_biallelic, df_nodrivers])


number_of_drivers = pd.concat([number_of_drivers_WT, number_of_drivers_LP, number_of_drivers_het, 
                               number_of_drivers_biallelic])


number_of_drivers = number_of_drivers.fillna(0)

number_of_drivers.head()
# Out:
# (9147, 3) (211, 3) (400, 2)
#                 Tumor_Sample  n_all_drivers allele_state
# 0  A-c0cfec74b8666bf-T01-IM5            1.0     WildType
# 1     A-fb1cda9f4919-T02-IM5            4.0     WildType
# 3     A-0c2e7b660c55-T01-IM5            1.0     WildType
# 4  A-faf64244d53dbc7-T01-IM6            2.0     WildType
# 5     A-547e0bd9bf8e-T01-IM5            3.0     WildType

# %%
#number_of_drivers
from scipy.stats import ttest_ind, ttest_ind_from_stats
list_WT = number_of_drivers[(number_of_drivers['allele_state']=='WildType')]['n_all_drivers'].tolist()
list_MLU = number_of_drivers[(number_of_drivers['allele_state']=='M/L/U')]['n_all_drivers'].tolist()
list_Biallelic = number_of_drivers[(number_of_drivers['allele_state']=='Biallelic')]['n_all_drivers'].tolist()
list_Het = number_of_drivers[(number_of_drivers['allele_state']=='Heterozygous')]['n_all_drivers'].tolist()

#compute p-values. The exact p-values may be different from what's reported due to the sampling differences 
#every run would provide a slightly different set of wildtype and lower penetrance patients
print "\n anova"
t, pval = stats.f_oneway(list_WT, list_Het,list_MLU, list_Biallelic) #anova
print pval

from statsmodels.stats.multicomp import pairwise_tukeyhsd
print pairwise_tukeyhsd(number_of_drivers['n_all_drivers'], number_of_drivers['allele_state'])

f, ax = plt.subplots(figsize=(1.5, 4))
sns.set(font_scale=1.5)
sns.set_style("whitegrid", {"axes.facecolor": "white"})
sns.set(style="ticks")

                #label='big')inner="quartile", 
#ax = sns.catplot(x="allele_state", y="driver_count", kind="box", data=number_of_drivers);

ax = sns.boxplot(x="allele_state", y="n_all_drivers",data=number_of_drivers,showfliers = False,width = 0.6,
                 notch = False,
                palette={"WildType": "#fb9a99", "Heterozygous": 'teal', "Biallelic": "navy", 
                         "M/L/U": "green"
                        } )#inner="quartile", )
# ax = sns.stripplot(x="allele_state", y="driver_count",edgecolor='black',
#                   linewidth=1,
#                  data=number_of_drivers, dodge=True, jitter = True,)

ax.set_ylabel('Number of somatic drivers per patient')
ax.set_xlabel('')
#ax.set_ylim([0, 10])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
#  anova
# 1.0079022997056931e-06
#    Multiple Comparison of Means - Tukey HSD,FWER=0.05
# ========================================================
#    group1       group2    meandiff  lower  upper  reject
# --------------------------------------------------------
#  Biallelic   Heterozygous  0.633    0.1115 1.1545  True
#  Biallelic      M/L/U      0.7033   0.3609 1.0458  True
#  Biallelic     WildType    0.6622   0.3491 0.9753  True
# Heterozygous    M/L/U      0.0704  -0.3784 0.5191 False
# Heterozygous   WildType    0.0292  -0.3976 0.456  False
#    M/L/U       WildType   -0.0412  -0.2068 0.1245 False
# --------------------------------------------------------
# [Text(0,0,'WildType'),
#  Text(0,0,'M/L/U'),
#  Text(0,0,'Heterozygous'),
#  Text(0,0,'Biallelic')]

# %%
somatic_oncogenic_status.head()
# Out:
#           Patient_ID               Tumor_Sample  n_drivers  n_all_drivers  \
# 0  A-c0cfec74b8666bf  A-c0cfec74b8666bf-T01-IM5        0.0            1.0
# 1     A-fb1cda9f4919     A-fb1cda9f4919-T02-IM5        1.0            4.0
# 2     A-c3446f9e3370     A-c3446f9e3370-T01-IM6        0.0            6.0
# 3     A-0c2e7b660c55     A-0c2e7b660c55-T01-IM5        1.0            1.0
# 4  A-faf64244d53dbc7  A-faf64244d53dbc7-T01-IM6        1.0            2.0
#
#                       cancer_type penetrance  bi-allelic  penetrance_order  \
# 0                 Prostate Cancer        NaN         NaN               NaN
# 1  Gastrointestinal Stromal Tumor        NaN         NaN               NaN
# 2                  Ovarian Cancer        Low         0.0               3.0
# 3                           Other        NaN         NaN               NaN
# 4       Colorectal Adenocarcinoma        NaN         NaN               NaN
#
#   gl_status
# 0  wildtype
# 1  wildtype
# 2     M/L/U
# 3  wildtype
# 4  wildtype

# %%
somatic_mutations_sub = somatic_oncogenic_status[somatic_oncogenic_status['n_drivers']>0]

somatic_mutations_sub['allele_state'] = np.where(somatic_mutations_sub['Patient_ID'].isin(pts_hi_pen_biallelic), 'Biallelic',
                                               'WildType-Het')# somatic_mutations_sub['allele_state']) #)

clinical_data_sub = clinical_data[['Patient_ID', 'cancer_type']]

clinical_data_sub['allele_state'] = np.where(clinical_data_sub['Patient_ID'].isin(pts_hi_pen_biallelic), 'Biallelic',
                                               'WildType-Het' ) #clinical_data_sub['allele_state'] )


tumorcount = pd.DataFrame({
        'tumorcount' : 
        clinical_data_sub.groupby(['cancer_type','allele_state'])['Patient_ID'].nunique()
    }).reset_index()
print tumorcount.head()

rate_drivers = pd.DataFrame({
        'driver_count' : 
        somatic_mutations_sub[somatic_mutations_sub['n_drivers']>0].groupby(['cancer_type','allele_state'])['Patient_ID'].nunique()
    }).reset_index()
print "\n\n"
print rate_drivers.head()
print rate_drivers.dtypes
print tumorcount.dtypes
rate_drivers = pd.merge(rate_drivers, tumorcount, on = ['cancer_type', 'allele_state'], 
                        how = 'left')
rate_drivers.head()
# Out:
#                 cancer_type  allele_state  tumorcount
# 0  Adrenocortical Carcinoma     Biallelic           2
# 1  Adrenocortical Carcinoma  WildType-Het          30
# 2       Ampullary Carcinoma     Biallelic           3
# 3       Ampullary Carcinoma  WildType-Het          34
# 4               Anal Cancer  WildType-Het          40
#
#
#
#                   cancer_type  allele_state  driver_count
# 0    Adrenocortical Carcinoma  WildType-Het             4
# 1         Ampullary Carcinoma     Biallelic             2
# 2         Ampullary Carcinoma  WildType-Het            26
# 3                 Anal Cancer  WildType-Het            15
# 4  Appendiceal Adenocarcinoma  WildType-Het            66
# cancer_type     object
# allele_state    object
# driver_count     int64
# dtype: object
# cancer_type     object
# allele_state    object
# tumorcount       int64
# dtype: object
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                   cancer_type  allele_state  driver_count  tumorcount
# 0    Adrenocortical Carcinoma  WildType-Het             4          30
# 1         Ampullary Carcinoma     Biallelic             2           3
# 2         Ampullary Carcinoma  WildType-Het            26          34
# 3                 Anal Cancer  WildType-Het            15          40
# 4  Appendiceal Adenocarcinoma  WildType-Het            66          91

# %%
rate_drivers['somatic_no_driver'] = rate_drivers['tumorcount'] - rate_drivers['driver_count']
rate_drivers['proportion'] = rate_drivers['driver_count']/rate_drivers['tumorcount']
print rate_drivers.head()

rate_drivers['cancer_type'] = rate_drivers['cancer_type'].str.replace("_", " ")


plot_tumors = rate_drivers[(rate_drivers['allele_state']=='Biallelic') &
                           (rate_drivers['tumorcount']>=5)]['cancer_type'].unique().tolist()
rate_drivers_plot = rate_drivers[rate_drivers['cancer_type'].isin(plot_tumors)]
rate_drivers_plot = rate_drivers_plot[~(rate_drivers_plot['cancer_type']=='EXCLUDE')]
print rate_drivers_plot.head()

f, ax = plt.subplots(figsize=(8, 4))
sns.set(font_scale=1.5)
sns.set_style("whitegrid", {"axes.facecolor": "white"})
sns.set(style="ticks")

order_tumortypes =[ 'Gastrointestinal Stromal Tumor', 'Invasive Breast Carcinoma',
                   'Ovarian Cancer', 
                   'Non-Small Cell Lung Cancer','Endometrial Carcinoma','Cholangiocarcinoma', 
                   'Prostate Cancer', 'Esophagogastric Cancer', 
                   'Diffuse Glioma',  'Bone Cancer','Colorectal Adenocarcinoma', 'Pancreatic Adenocarcinoma',]
order_tumortypes = ['Invasive Breast Carcinoma', 'Gastrointestinal Stromal Tumor', 'Ovarian Cancer', 'Non-Small Cell Lung Cancer', 'Endometrial Carcinoma', 'Diffuse Glioma', 'Prostate Cancer', 'Esophagogastric Cancer', 'Bone Cancer', 'Cholangiocarcinoma', 'Colorectal Adenocarcinoma', 'Pancreatic Adenocarcinoma']
                   
order_tumortypes = [i for i in order_tumortypes if i not in ['Other', 'Nerve Sheath Tumor', 'Cancer of Unknown Primary']]

dict_tumor_index = {k: v for v, k in enumerate(order_tumortypes)}


rate_drivers_plot['order'] = rate_drivers_plot['cancer_type'].map(dict_tumor_index)
rate_drivers_plot = rate_drivers_plot[rate_drivers_plot['cancer_type'].isin(order_tumortypes)]
rate_drivers_plot = rate_drivers_plot.sort_values('order')
ax = sns.barplot(x="cancer_type", y="proportion",data=rate_drivers_plot,
                 hue = 'allele_state', 
                 palette={"WildType-Het": "darkgrey",#"#0a69ad", 
                           "Biallelic": "black"},# "#80cdbb"},
                hue_order = ['WildType-Het','Biallelic'])

ax.set_ylabel('Proportion of patients with somatic driver')
ax.set_xlabel('')
ax.set_ylim([0, 1])
ax.legend(loc='upper left', bbox_to_anchor=(1.05, 0.7),
           fancybox=True, shadow=False)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
#                   cancer_type  allele_state  driver_count  tumorcount  \
# 0    Adrenocortical Carcinoma  WildType-Het             4          30
# 1         Ampullary Carcinoma     Biallelic             2           3
# 2         Ampullary Carcinoma  WildType-Het            26          34
# 3                 Anal Cancer  WildType-Het            15          40
# 4  Appendiceal Adenocarcinoma  WildType-Het            66          91
#
#    somatic_no_driver  proportion
# 0                 26    0.133333
# 1                  1    0.666667
# 2                  8    0.764706
# 3                 25    0.375000
# 4                 25    0.725275
#                   cancer_type  allele_state  driver_count  tumorcount  \
# 7                 Bone Cancer     Biallelic             1           9
# 8                 Bone Cancer  WildType-Het            26         165
# 9   Cancer of Unknown Primary     Biallelic             5           8
# 10  Cancer of Unknown Primary  WildType-Het           159         288
# 12         Cholangiocarcinoma     Biallelic             5           8
#
#     somatic_no_driver  proportion
# 7                   8    0.111111
# 8                 139    0.157576
# 9                   3    0.625000
# 10                129    0.552083
# 12                  3    0.625000
# [Text(0,0,'Invasive Breast Carcinoma'),
#  Text(0,0,'Gastrointestinal Stromal Tumor'),
#  Text(0,0,'Ovarian Cancer'),
#  Text(0,0,'Non-Small Cell Lung Cancer'),
#  Text(0,0,'Endometrial Carcinoma'),
#  Text(0,0,'Diffuse Glioma'),
#  Text(0,0,'Prostate Cancer'),
#  Text(0,0,'Esophagogastric Cancer'),
#  Text(0,0,'Bone Cancer'),
#  Text(0,0,'Cholangiocarcinoma'),
#  Text(0,0,'Colorectal Adenocarcinoma'),
#  Text(0,0,'Pancreatic Adenocarcinoma')]

# %%
rate_drivers_plot
# Out:
#                        cancer_type  allele_state  driver_count  tumorcount  \
# 33       Invasive Breast Carcinoma  WildType-Het          1149        1994
# 32       Invasive Breast Carcinoma     Biallelic            26         107
# 28  Gastrointestinal Stromal Tumor     Biallelic             1          11
# 29  Gastrointestinal Stromal Tumor  WildType-Het           156         180
# 47                  Ovarian Cancer  WildType-Het            98         297
# 46                  Ovarian Cancer     Biallelic             3          27
# 41      Non-Small Cell Lung Cancer  WildType-Het          1424        1820
# 40      Non-Small Cell Lung Cancer     Biallelic            15          26
# 22           Endometrial Carcinoma     Biallelic             3           7
# 23           Endometrial Carcinoma  WildType-Het           294         376
# 18                  Diffuse Glioma     Biallelic             3           6
# 19                  Diffuse Glioma  WildType-Het           565         743
# 52                 Prostate Cancer  WildType-Het           309         811
# 51                 Prostate Cancer     Biallelic            12          41
# 25          Esophagogastric Cancer  WildType-Het           149         312
# 24          Esophagogastric Cancer     Biallelic             4          12
# 8                      Bone Cancer  WildType-Het            26         165
# 7                      Bone Cancer     Biallelic             1           9
# 13              Cholangiocarcinoma  WildType-Het           154         236
# 12              Cholangiocarcinoma     Biallelic             5           8
# 15       Colorectal Adenocarcinoma  WildType-Het           787        1205
# 14       Colorectal Adenocarcinoma     Biallelic             3           5
# 48       Pancreatic Adenocarcinoma     Biallelic            39          40
# 49       Pancreatic Adenocarcinoma  WildType-Het           567         595
#
#     somatic_no_driver  proportion  order
# 33                845    0.576229    0.0
# 32                 81    0.242991    0.0
# 28                 10    0.090909    1.0
# 29                 24    0.866667    1.0
# 47                199    0.329966    2.0
# 46                 24    0.111111    2.0
# 41                396    0.782418    3.0
# 40                 11    0.576923    3.0
# 22                  4    0.428571    4.0
# 23                 82    0.781915    4.0
# 18                  3    0.500000    5.0
# 19                178    0.760431    5.0
# 52                502    0.381011    6.0
# 51                 29    0.292683    6.0
# 25                163    0.477564    7.0
# 24                  8    0.333333    7.0
# 8                 139    0.157576    8.0
# 7                   8    0.111111    8.0
# 13                 82    0.652542    9.0
# 12                  3    0.625000    9.0
# 15                418    0.653112   10.0
# 14                  2    0.600000   10.0
# 48                  1    0.975000   11.0
# 49                 28    0.952941   11.0

# %%
import scipy
import scipy.stats as stats

rate_drivers_plot = rate_drivers_plot.fillna(0)
rate_drivers_plot = rate_drivers_plot.pivot_table(index = 'cancer_type', columns = ['allele_state'], 
                                       values = ['driver_count', 'somatic_no_driver'])

rate_drivers_plot = rate_drivers_plot.fillna(0)
print rate_drivers_plot.head()
rate_drivers_plot.columns = ['drivers_biallelic',  'drivers_wt', "nodriver_biallelic",
                       'nodriver_wt']

# rate_drivers['fishers_pvalue_WT_vs_Het'] =  rate_drivers.apply(
#         lambda r: scipy.stats.fisher_exact([[r.drivers_wt, r.nodriver_wt ],
#                                             [r.drivers_het, r.nodriver_het]], alternative= 'greater')[1],
#         axis=1)

# rate_drivers['fishers_pvalue_Het_vs_Biallelic'] =  rate_drivers.apply(
#         lambda r: scipy.stats.fisher_exact([[r.drivers_het, r.nodriver_het],
#                                             [r.drivers_biallelic, r.nodriver_biallelic]], alternative= 'greater')[1],
#         axis=1)

rate_drivers_plot['fishers_pvalue_WT_vs_Biallelic'] =  rate_drivers_plot.apply(
        lambda r: scipy.stats.fisher_exact([[r.drivers_wt, r.nodriver_wt ],
                                            [r.drivers_biallelic, r.nodriver_biallelic]])[1],#alternative= 'greater')[1],
        axis=1)
rate_drivers_plot['odds_ratio'] =  rate_drivers_plot.apply(
        lambda r: scipy.stats.fisher_exact([[r.drivers_wt, r.nodriver_wt ],
                                            [r.drivers_biallelic, r.nodriver_biallelic]])[0],#alternative= 'greater')[1],
        axis=1)
adj_pval_all = statsmodels.sandbox.stats.multicomp.multipletests(rate_drivers_plot['fishers_pvalue_WT_vs_Biallelic'], 
                                                                 alpha=0.05, method='bonferroni', is_sorted=False)
rate_drivers_plot['FishersExact_BH_WTvsBi']  = np.array(adj_pval_all[1])


rate_drivers_plot = rate_drivers_plot.sort_values('fishers_pvalue_WT_vs_Biallelic')
rate_drivers_plot = rate_drivers_plot.reset_index()
order_tumortypes = rate_drivers_plot['cancer_type'].tolist()
print order_tumortypes
rate_drivers_plot[(rate_drivers_plot['FishersExact_BH_WTvsBi']<0.05) ]
# Out:
#                           driver_count              somatic_no_driver  \
# allele_state                 Biallelic WildType-Het         Biallelic
# cancer_type
# Bone Cancer                          1           26                 8
# Cholangiocarcinoma                   5          154                 3
# Colorectal Adenocarcinoma            3          787                 2
# Diffuse Glioma                       3          565                 3
# Endometrial Carcinoma                3          294                 4
#
#
# allele_state              WildType-Het
# cancer_type
# Bone Cancer                        139
# Cholangiocarcinoma                  82
# Colorectal Adenocarcinoma          418
# Diffuse Glioma                     178
# Endometrial Carcinoma               82
# ['Invasive Breast Carcinoma', 'Gastrointestinal Stromal Tumor', 'Ovarian Cancer', 'Non-Small Cell Lung Cancer', 'Endometrial Carcinoma', 'Diffuse Glioma', 'Prostate Cancer', 'Esophagogastric Cancer', 'Bone Cancer', 'Cholangiocarcinoma', 'Colorectal Adenocarcinoma', 'Pancreatic Adenocarcinoma']
#                       cancer_type  drivers_biallelic  drivers_wt  \
# 0       Invasive Breast Carcinoma                 26        1149
# 1  Gastrointestinal Stromal Tumor                  1         156
#
#    nodriver_biallelic  nodriver_wt  fishers_pvalue_WT_vs_Biallelic  \
# 0                  81          845                    1.077013e-11
# 1                  10           24                    9.053016e-08
#
#    odds_ratio  FishersExact_BH_WTvsBi
# 0    4.236186            1.292416e-10
# 1   65.000000            1.086362e-06

# %%
rate_drivers_plot.sort_values('fishers_pvalue_WT_vs_Biallelic', ascending = True)
# Out:
#                        cancer_type  drivers_biallelic  drivers_wt  \
# 0        Invasive Breast Carcinoma                 26        1149
# 1   Gastrointestinal Stromal Tumor                  1         156
# 2                   Ovarian Cancer                  3          98
# 3       Non-Small Cell Lung Cancer                 15        1424
# 4            Endometrial Carcinoma                  3         294
# 5                   Diffuse Glioma                  3         565
# 6                  Prostate Cancer                 12         309
# 7           Esophagogastric Cancer                  4         149
# 8                      Bone Cancer                  1          26
# 9               Cholangiocarcinoma                  5         154
# 10       Colorectal Adenocarcinoma                  3         787
# 11       Pancreatic Adenocarcinoma                 39         567
#
#     nodriver_biallelic  nodriver_wt  fishers_pvalue_WT_vs_Biallelic  \
# 0                   81          845                    1.077013e-11
# 1                   10           24                    9.053016e-08
# 2                   24          199                    1.718554e-02
# 3                   11          396                    1.730806e-02
# 4                    4           82                    4.781892e-02
# 5                    3          178                    1.556436e-01
# 6                   29          502                    3.219157e-01
# 7                    8          163                    3.878004e-01
# 8                    8          139                    1.000000e+00
# 9                    3           82                    1.000000e+00
# 10                   2          418                    1.000000e+00
# 11                   1           28                    1.000000e+00
#
#     odds_ratio  FishersExact_BH_WTvsBi
# 0     4.236186            1.292416e-10
# 1    65.000000            1.086362e-06
# 2     3.939698            2.062265e-01
# 3     2.637037            2.076967e-01
# 4     4.780488            5.738270e-01
# 5     3.174157            1.000000e+00
# 6     1.487550            1.000000e+00
# 7     1.828221            1.000000e+00
# 8     1.496403            1.000000e+00
# 9     1.126829            1.000000e+00
# 10    1.255183            1.000000e+00
# 11    0.519231            1.000000e+00

# %%
print rate_drivers_plot.sort_values('fishers_pvalue_WT_vs_Biallelic', ascending = True)['cancer_type'].tolist()
# Out:
# ['Invasive Breast Carcinoma', 'Gastrointestinal Stromal Tumor', 'Ovarian Cancer', 'Non-Small Cell Lung Cancer', 'Endometrial Carcinoma', 'Diffuse Glioma', 'Prostate Cancer', 'Esophagogastric Cancer', 'Bone Cancer', 'Cholangiocarcinoma', 'Colorectal Adenocarcinoma', 'Pancreatic Adenocarcinoma']
